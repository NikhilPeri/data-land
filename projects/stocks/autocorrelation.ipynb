# %%
import os
os.chdir('/Users/nikhilperi/github.com/NikhilPeri/data-land')

import time
import pandas as pd
from projects.stocks.api import get_daily_prices

companies = pd.read_csv('data/stocks/snp_500_list.csv')

# %%
RATE_LIMITER = 2

prices = get_daily_prices('BF%2EB', full=True)
prices.to_csv('data/stocks/prices/{}.csv'.format('BF.B'), mode='w+', index=False)

# %%
companies
# Out:
#     Symbol                                 Name                  Sector  \
# 0      MMM                           3M Company             Industrials
# 1      AOS                      A.O. Smith Corp             Industrials
# 2      ABT                  Abbott Laboratories             Health Care
# 3     ABBV                          AbbVie Inc.             Health Care
# 4      ACN                        Accenture plc  Information Technology
# 5     ATVI                  Activision Blizzard  Information Technology
# 6      AYI                    Acuity Brands Inc             Industrials
# 7     ADBE                    Adobe Systems Inc  Information Technology
# 8      AAP                   Advance Auto Parts  Consumer Discretionary
# 9      AMD           Advanced Micro Devices Inc  Information Technology
# 10     AES                             AES Corp               Utilities
# 11     AET                            Aetna Inc             Health Care
# ...
