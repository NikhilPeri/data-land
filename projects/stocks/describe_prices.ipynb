# %%
import os
os.chdir('/Users/nikhilperi/github.com/NikhilPeri/data-land')

import pandas as pd
from sklearn.preprocessing import minmax_scale

# %%
stock_list = pd.read_csv('data/stocks/snp_500_list.csv')

# %%
stock_list.head()
# Out:
#   Symbol                 Name                  Sector  price_count  \
# 0    MMM           3M Company             Industrials       5942.0
# 1    AOS      A.O. Smith Corp             Industrials       5942.0
# 2    ABT  Abbott Laboratories             Health Care       5942.0
# 3   ABBV          AbbVie Inc.             Health Care       1410.0
# 4    ACN        Accenture plc  Information Technology       4290.0
#
#    intraday_mean  intraday_stddev
# 0         0.0133           0.0085
# 1         0.0164           0.0090
# 2         0.0143           0.0073
# 3         0.0207           0.0140
# 4         0.0133           0.0073

# %% [markdown]
# # Intraday Stats
#
# Our goal is to maximize the intraday mean while minimizing the intraday standard deviation. This will help us find a stock that trades with high daily change but with low day to day volitility, we can use the following scoring function:
#
# ```
# score = weight_daily_change*normalized(intraday_mean) - weight_volitility*normalized(intraday_stddev)
# ```

# %%
WEIGHT_DAILY_CHANGE = 1.0
WEIGHT_VOLITILITY = -1.0

stock_list['intraday_score'] = WEIGHT_DAILY_CHANGE * minmax_scale(stock_list['intraday_mean']) - WEIGHT_VOLITILITY * minmax_scale(stock_list['intraday_stddev'])
stock_list.sort_values('intraday_score', ascending=False).head(10)
# Out:
#     Symbol                        Name                  Sector  price_count  \
# 325   NKTR         Nektar Therapeutics             Health Care       5942.0
# 9      AMD  Advanced Micro Devices Inc  Information Technology       5942.0
# 299    MAT                 Mattel Inc.  Consumer Discretionary       5942.0
# 458     UA        Under Armour Class C  Consumer Discretionary        589.0
# 457    UAA        Under Armour Class A  Consumer Discretionary       3200.0
# 450   TRIP                 TripAdvisor  Consumer Discretionary       1677.0
# 385    RRC       Range Resources Corp.                  Energy       5942.0
# 310     MU           Micron Technology  Information Technology       5942.0
# 169   EVHC         Envision Healthcare             Health Care       1255.0
# 291      M                 Macy's Inc.  Consumer Discretionary       5942.0
#
#      intraday_mean  intraday_stddev  intraday_score
# 325         0.0525           0.0334        2.000000
# 9           0.0400           0.0194        1.224062
# 299         0.0324           0.0218        1.142006
# 458         0.0348           0.0188        1.087843
# 457         0.0352           0.0179        1.064530
# 450         0.0320           0.0189        1.029604
# 385         0.0366           0.0143        0.966864
# 310         0.0329           0.0163        0.956615
# 169         0.0277           0.0189        0.934681
# 291         0.0323           0.0159        0.929084
